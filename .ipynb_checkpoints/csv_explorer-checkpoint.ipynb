# %%
# %matplotlib inline
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt

df = pd.read_csv('list.csv')
print df.columns

#TODO: handle the datetime
"""
= df['last_updated'].apply()
print "num_open_issues vs last_updated"
plt.scatter(df['last_updated'], df['num_open_issues'],s=2)
plt.show()
"""

print "stars vs watches"
plt.scatter(df['num_watch'], df['num_stars'],s=2)
plt.show()

print "forks vs watches"
plt.scatter(df['num_watch'], df['num_forks'],s=2)
plt.show()
# Out:
# Index([u'name', u'url', u'author', u'num_watch', u'num_stars', u'num_forks', u'num_open_issues', u'last_updated'], dtype='object')
# stars vs watches
# forks vs watches

# %%
df['forks_per_watch'] = df['num_forks'] / df['num_watch']

result = df.sort(columns=['forks_per_watch'], ascending=False)

print result
# Out:
#                                              name  \
# 134                           jsonauts.github.com
# 260                             awesome-cassandra
# 29                                        recipes
# 35                      sf-vegetarian-restaurants
# 30                                        recipes
# 206              static-site-generator-comparison
# 219                                 twofactorauth
# 26                                        recipes
# 221                        universities-on-github
# 142                         learnxinyminutes-docs
# 230                       awesome-2048-and-beyond
# 173                                      Projects
# 440                            awesome-collection
# 84                            devopsbookmarks.com
# 100                        free-programming-books
# 43                      android-awesome-libraries
# 66                                   bookmarklets
# 82                                             go
# ...
